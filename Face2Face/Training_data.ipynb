# %%
import os
import cv2
import dlib
import time
import argparse
import numpy as np
from imutils import video

DOWNSAMPLE_RATIO = 4


def reshape_for_polyline(array):
    return np.array(array, np.int32).reshape((-1, 1, 2))


def main():
    os.makedirs('original', exist_ok=True)
    os.makedirs('landmarks', exist_ok=True)

    cap = cv2.VideoCapture("C:/Users/Thiya/Desktop/Wayne/Sofwerx/Project/photos1/Face2Facemodel/Angela.mp4")#args.filename)
    fps = video.FPS().start()

    count = 0
    while cap.isOpened():
        ret, frame = cap.read()

        frame_resize = cv2.resize(frame, None, fx=1 / DOWNSAMPLE_RATIO, fy=1 / DOWNSAMPLE_RATIO)
        gray = cv2.cvtColor(frame_resize, cv2.COLOR_BGR2GRAY)
        faces = detector(gray, 1)
        black_image = np.zeros(frame.shape, np.uint8)

        t = time.time()

        # Perform if there is a face detected
        if len(faces) == 1:
            for face in faces:
                detected_landmarks = predictor(gray, face).parts()
                landmarks = [[p.x * DOWNSAMPLE_RATIO, p.y * DOWNSAMPLE_RATIO] for p in detected_landmarks]

                jaw = reshape_for_polyline(landmarks[0:17])
                left_eyebrow = reshape_for_polyline(landmarks[22:27])
                right_eyebrow = reshape_for_polyline(landmarks[17:22])
                nose_bridge = reshape_for_polyline(landmarks[27:31])
                lower_nose = reshape_for_polyline(landmarks[30:35])
                left_eye = reshape_for_polyline(landmarks[42:48])
                right_eye = reshape_for_polyline(landmarks[36:42])
                outer_lip = reshape_for_polyline(landmarks[48:60])
                inner_lip = reshape_for_polyline(landmarks[60:68])

                color = (255, 255, 255)
                thickness = 3

                cv2.polylines(black_image, [jaw], False, color, thickness)
                cv2.polylines(black_image, [left_eyebrow], False, color, thickness)
                cv2.polylines(black_image, [right_eyebrow], False, color, thickness)
                cv2.polylines(black_image, [nose_bridge], False, color, thickness)
                cv2.polylines(black_image, [lower_nose], True, color, thickness)
                cv2.polylines(black_image, [left_eye], True, color, thickness)
                cv2.polylines(black_image, [right_eye], True, color, thickness)
                cv2.polylines(black_image, [outer_lip], True, color, thickness)
                cv2.polylines(black_image, [inner_lip], True, color, thickness)

            # Display the resulting frame
            count += 1
            print(count)
            cv2.imwrite("original/{}.png".format(count), frame)
            cv2.imwrite("landmarks/{}.png".format(count), black_image)
            fps.update()

            print('[INFO] elapsed time: {:.2f}'.format(time.time() - t))

            if count == 400: #args.number:  # only take 400 photos
                break
            elif cv2.waitKey(1) & 0xFF == ord('q'):
                break
        else:
            print("No face detected")

    fps.stop()
    print('[INFO] elapsed time (total): {:.2f}'.format(fps.elapsed()))
    print('[INFO] approx. FPS: {:.2f}'.format(fps.fps()))

    cap.release()
    cv2.destroyAllWindows()


if __name__ == '__main__':
    os.chdir("C:/Users/Thiya/Desktop/Wayne/Sofwerx/Project/")
    parser = argparse.ArgumentParser()
    parser.add_argument('--file', dest='filename', type=str, help='Name of the video file.')
    parser.add_argument('--num', dest='number', type=int, help='Number of train data to be created.')
    parser.add_argument('--landmark-model', dest='face_landmark_shape_file', type=str, help='Face landmark model file.')
    args = parser.parse_known_args()
    #args = parser.parse_args()

    # Create the face predictor and landmark predictor
    detector = dlib.get_frontal_face_detector()
    predictor = dlib.shape_predictor("C:/Users/Thiya/Desktop/Wayne/Sofwerx/Project/photos1/Face2Facemodel/shape_predictor_68_face_landmarks.dat") #args.face_landmark_shape_file)
    main()
# Out:
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# No face detected
# 1
# [INFO] elapsed time: 0.25
# 2
# [INFO] elapsed time: 0.05
# 3
# [INFO] elapsed time: 0.05
# 4
# [INFO] elapsed time: 0.21
# 5
# [INFO] elapsed time: 0.30
# 6
# [INFO] elapsed time: 0.26
# 7
# [INFO] elapsed time: 0.47
# 8
# [INFO] elapsed time: 0.30
# 9
# [INFO] elapsed time: 0.26
# 10
# [INFO] elapsed time: 0.27
# 11
# [INFO] elapsed time: 0.30
# 12
# [INFO] elapsed time: 0.07
# 13
# [INFO] elapsed time: 0.05
# 14
# [INFO] elapsed time: 0.05
# 15
# [INFO] elapsed time: 0.06
# 16
# [INFO] elapsed time: 0.06
# 17
# [INFO] elapsed time: 0.05
# 18
# [INFO] elapsed time: 0.05
# 19
# [INFO] elapsed time: 0.06
# 20
# [INFO] elapsed time: 0.05
# 21
# [INFO] elapsed time: 0.15
# 22
# [INFO] elapsed time: 0.05
# 23
# [INFO] elapsed time: 0.07
# 24
# [INFO] elapsed time: 0.07
# 25
# [INFO] elapsed time: 0.17
# 26
# [INFO] elapsed time: 0.28
# 27
# [INFO] elapsed time: 0.31
# 28
# [INFO] elapsed time: 0.33
# 29
# [INFO] elapsed time: 1.24
# 30
# [INFO] elapsed time: 0.38
# 31
# [INFO] elapsed time: 0.20
# 32
# [INFO] elapsed time: 0.08
# 33
# [INFO] elapsed time: 0.12
# 34
# [INFO] elapsed time: 0.07
# 35
# [INFO] elapsed time: 0.06
# 36
# [INFO] elapsed time: 0.07
# 37
# [INFO] elapsed time: 0.06
# 38
# [INFO] elapsed time: 0.18
# 39
# [INFO] elapsed time: 0.11
# 40
# [INFO] elapsed time: 0.09
# 41
# [INFO] elapsed time: 0.09
# 42
# [INFO] elapsed time: 0.11
# 43
# [INFO] elapsed time: 0.06
# 44
# [INFO] elapsed time: 0.06
# 45
# [INFO] elapsed time: 0.09
# 46
# [INFO] elapsed time: 0.11
# 47
# [INFO] elapsed time: 0.06
# 48
# [INFO] elapsed time: 0.06
# 49
# [INFO] elapsed time: 0.06
# 50
# [INFO] elapsed time: 0.06
# 51
# [INFO] elapsed time: 0.07
# 52
# [INFO] elapsed time: 0.07
# 53
# [INFO] elapsed time: 0.08
# 54
# [INFO] elapsed time: 0.05
# 55
# [INFO] elapsed time: 0.05
# 56
# [INFO] elapsed time: 0.13
# 57
# [INFO] elapsed time: 0.05
# 58
# [INFO] elapsed time: 0.05
# 59
# [INFO] elapsed time: 0.08
# 60
# [INFO] elapsed time: 0.05
# 61
# [INFO] elapsed time: 0.05
# 62
# [INFO] elapsed time: 0.08
# 63
# [INFO] elapsed time: 0.29
# 64
# [INFO] elapsed time: 0.31
# 65
# [INFO] elapsed time: 0.34
# 66
# [INFO] elapsed time: 0.36
# 67
# [INFO] elapsed time: 0.53
# 68
# [INFO] elapsed time: 0.29
# 69
# [INFO] elapsed time: 0.05
# 70
# [INFO] elapsed time: 0.06
# 71
# [INFO] elapsed time: 0.05
# 72
# [INFO] elapsed time: 0.13
# 73
# [INFO] elapsed time: 0.08
# 74
# [INFO] elapsed time: 0.05
# 75
# [INFO] elapsed time: 0.06
# 76
# [INFO] elapsed time: 0.07
# 77
# [INFO] elapsed time: 0.06
# 78
# [INFO] elapsed time: 0.05
# 79
# [INFO] elapsed time: 0.08
# 80
# [INFO] elapsed time: 0.09
# 81
# [INFO] elapsed time: 0.06
# 82
# [INFO] elapsed time: 0.04
# 83
# [INFO] elapsed time: 0.15
# 84
# [INFO] elapsed time: 0.07
# 85
# [INFO] elapsed time: 0.05
# 86
# [INFO] elapsed time: 0.25
# 87
# [INFO] elapsed time: 0.04
# 88
# [INFO] elapsed time: 0.05
# 89
# [INFO] elapsed time: 0.06
# 90
# [INFO] elapsed time: 0.07
# 91
# [INFO] elapsed time: 0.04
# 92
# [INFO] elapsed time: 0.05
# 93
# [INFO] elapsed time: 0.06
# 94
# [INFO] elapsed time: 0.08
# 95
# [INFO] elapsed time: 0.05
# 96
# [INFO] elapsed time: 0.05
# 97
# [INFO] elapsed time: 0.05
# 98
# [INFO] elapsed time: 0.14
# 99
# [INFO] elapsed time: 0.06
# 100
# [INFO] elapsed time: 0.05
# 101
# [INFO] elapsed time: 0.05
# 102
# [INFO] elapsed time: 0.05
# 103
# [INFO] elapsed time: 0.08
# 104
# [INFO] elapsed time: 0.05
# 105
# [INFO] elapsed time: 0.07
# 106
# [INFO] elapsed time: 0.06
# 107
# [INFO] elapsed time: 0.06
# 108
# [INFO] elapsed time: 0.05
# 109
# [INFO] elapsed time: 0.12
# 110
# [INFO] elapsed time: 0.05
# 111
# [INFO] elapsed time: 0.05
# 112
# [INFO] elapsed time: 0.06
# 113
# [INFO] elapsed time: 0.07
# 114
# [INFO] elapsed time: 0.07
# 115
# [INFO] elapsed time: 0.07
# 116
# [INFO] elapsed time: 0.09
# 117
# [INFO] elapsed time: 0.06
# 118
# [INFO] elapsed time: 0.06
# 119
# [INFO] elapsed time: 0.07
# 120
# [INFO] elapsed time: 0.07
# 121
# [INFO] elapsed time: 0.05
# 122
# [INFO] elapsed time: 0.06
# 123
# [INFO] elapsed time: 0.08
# 124
# [INFO] elapsed time: 0.10
# 125
# [INFO] elapsed time: 0.06
# 126
# [INFO] elapsed time: 0.05
# 127
# [INFO] elapsed time: 0.08
# 128
# [INFO] elapsed time: 0.07
# 129
# [INFO] elapsed time: 0.05
# 130
# [INFO] elapsed time: 0.07
# 131
# [INFO] elapsed time: 0.07
# 132
# [INFO] elapsed time: 0.05
# 133
# [INFO] elapsed time: 0.06
# 134
# [INFO] elapsed time: 0.08
# 135
# [INFO] elapsed time: 0.25
# 136
# [INFO] elapsed time: 0.47
# 137
# [INFO] elapsed time: 1.06
# 138
# [INFO] elapsed time: 2.58
# 139
# [INFO] elapsed time: 0.18
# 140
# [INFO] elapsed time: 0.09
# 141
# [INFO] elapsed time: 0.14
# 142
# [INFO] elapsed time: 0.10
# 143
# [INFO] elapsed time: 0.10
# 144
# [INFO] elapsed time: 0.18
# 145
# [INFO] elapsed time: 0.06
# 146
# [INFO] elapsed time: 0.09
# 147
# [INFO] elapsed time: 0.11
# 148
# [INFO] elapsed time: 0.07
# 149
# [INFO] elapsed time: 0.07
# 150
# [INFO] elapsed time: 0.10
# 151
# [INFO] elapsed time: 0.07
# 152
# [INFO] elapsed time: 0.10
# 153
# [INFO] elapsed time: 0.07
# 154
# [INFO] elapsed time: 0.09
# 155
# [INFO] elapsed time: 0.13
# 156
# [INFO] elapsed time: 0.08
# 157
# [INFO] elapsed time: 0.08
# 158
# [INFO] elapsed time: 0.08
# 159
# [INFO] elapsed time: 0.06
# 160
# [INFO] elapsed time: 0.08
# 161
# [INFO] elapsed time: 0.18
# 162
# [INFO] elapsed time: 0.08
# 163
# [INFO] elapsed time: 0.12
# 164
# [INFO] elapsed time: 0.12
# 165
# [INFO] elapsed time: 0.08
# 166
# [INFO] elapsed time: 0.08
# 167
# [INFO] elapsed time: 0.08
# 168
# [INFO] elapsed time: 0.13
# 169
# [INFO] elapsed time: 0.05
# 170
# [INFO] elapsed time: 0.05
# 171
# [INFO] elapsed time: 0.09
# 172
# [INFO] elapsed time: 0.07
# 173
# [INFO] elapsed time: 0.06
# 174
# [INFO] elapsed time: 0.06
# 175
# [INFO] elapsed time: 0.21
# 176
# [INFO] elapsed time: 0.06
# 177
# [INFO] elapsed time: 0.07
# 178
# [INFO] elapsed time: 0.16
# 179
# [INFO] elapsed time: 0.07
# 180
# [INFO] elapsed time: 0.07
# 181
# [INFO] elapsed time: 0.09
# 182
# [INFO] elapsed time: 0.07
# 183
# [INFO] elapsed time: 0.06
# 184
# [INFO] elapsed time: 0.10
# 185
# [INFO] elapsed time: 0.12
# 186
# [INFO] elapsed time: 0.07
# 187
# [INFO] elapsed time: 0.06
# 188
# [INFO] elapsed time: 0.52
# 189
# [INFO] elapsed time: 0.39
# 190
# [INFO] elapsed time: 0.46
# 191
# [INFO] elapsed time: 0.35
# 192
# [INFO] elapsed time: 1.00
# 193
# [INFO] elapsed time: 0.09
# 194
# [INFO] elapsed time: 0.07
# 195
# [INFO] elapsed time: 0.07
# 196
# [INFO] elapsed time: 0.08
# 197
# [INFO] elapsed time: 0.11
# 198
# [INFO] elapsed time: 0.14
# 199
# [INFO] elapsed time: 0.06
# 200
# [INFO] elapsed time: 0.07
# 201
# [INFO] elapsed time: 0.07
# 202
# [INFO] elapsed time: 0.18
# 203
# [INFO] elapsed time: 0.07
# 204
# [INFO] elapsed time: 0.07
# 205
# [INFO] elapsed time: 0.16
# 206
# [INFO] elapsed time: 0.07
# 207
# [INFO] elapsed time: 0.07
# 208
# [INFO] elapsed time: 0.14
# 209
# [INFO] elapsed time: 0.08
# 210
# [INFO] elapsed time: 0.13
# 211
# [INFO] elapsed time: 0.14
# 212
# [INFO] elapsed time: 0.08
# 213
# [INFO] elapsed time: 0.11
# 214
# [INFO] elapsed time: 0.06
# 215
# [INFO] elapsed time: 0.07
# 216
# [INFO] elapsed time: 0.07
# 217
# [INFO] elapsed time: 0.16
# 218
# [INFO] elapsed time: 0.08
# 219
# [INFO] elapsed time: 0.06
# 220
# [INFO] elapsed time: 0.12
# 221
# [INFO] elapsed time: 0.07
# 222
# [INFO] elapsed time: 0.05
# 223
# [INFO] elapsed time: 0.08
# 224
# [INFO] elapsed time: 0.14
# 225
# [INFO] elapsed time: 0.06
# 226
# [INFO] elapsed time: 0.14
# 227
# [INFO] elapsed time: 0.06
# 228
# [INFO] elapsed time: 0.06
# 229
# [INFO] elapsed time: 0.08
# 230
# [INFO] elapsed time: 0.21
# 231
# [INFO] elapsed time: 0.08
# 232
# [INFO] elapsed time: 0.24
# 233
# [INFO] elapsed time: 0.07
# 234
# [INFO] elapsed time: 0.33
# 235
# [INFO] elapsed time: 0.09
# 236
# [INFO] elapsed time: 0.18
# 237
# [INFO] elapsed time: 0.06
# 238
# [INFO] elapsed time: 0.16
# 239
# [INFO] elapsed time: 0.13
# 240
# [INFO] elapsed time: 0.30
# 241
# [INFO] elapsed time: 0.12
# 242
# [INFO] elapsed time: 0.12
# 243
# [INFO] elapsed time: 0.10
# 244
# [INFO] elapsed time: 0.10
# 245
# [INFO] elapsed time: 0.08
# 246
# [INFO] elapsed time: 0.10
# 247
# [INFO] elapsed time: 0.32
# 248
# [INFO] elapsed time: 0.09
# 249
# [INFO] elapsed time: 0.10
# 250
# [INFO] elapsed time: 0.07
# 251
# [INFO] elapsed time: 0.20
# 252
# [INFO] elapsed time: 0.07
# 253
# [INFO] elapsed time: 0.07
# 254
# [INFO] elapsed time: 0.10
# 255
# [INFO] elapsed time: 0.13
# 256
# [INFO] elapsed time: 0.05
# 257
# [INFO] elapsed time: 0.19
# 258
# [INFO] elapsed time: 0.07
# 259
# [INFO] elapsed time: 0.11
# 260
# [INFO] elapsed time: 0.08
# 261
# [INFO] elapsed time: 0.05
# 262
# [INFO] elapsed time: 0.15
# 263
# [INFO] elapsed time: 0.09
# 264
# [INFO] elapsed time: 0.05
# 265
# [INFO] elapsed time: 0.36
# 266
# [INFO] elapsed time: 0.15
# 267
# [INFO] elapsed time: 0.11
# 268
# [INFO] elapsed time: 0.10
# 269
# [INFO] elapsed time: 0.23
# 270
# [INFO] elapsed time: 0.10
# 271
# [INFO] elapsed time: 0.29
# 272
# [INFO] elapsed time: 0.20
# 273
# [INFO] elapsed time: 0.18
# 274
# [INFO] elapsed time: 0.13
# 275
# [INFO] elapsed time: 0.08
# 276
# [INFO] elapsed time: 0.18
# 277
# [INFO] elapsed time: 0.08
# 278
# [INFO] elapsed time: 0.08
# 279
# [INFO] elapsed time: 0.16
# 280
# [INFO] elapsed time: 0.10
# 281
# [INFO] elapsed time: 0.21
# 282
# [INFO] elapsed time: 0.20
# 283
# [INFO] elapsed time: 0.09
# 284
# [INFO] elapsed time: 0.18
# 285
# [INFO] elapsed time: 0.11
# 286
# [INFO] elapsed time: 0.28
# 287
# [INFO] elapsed time: 0.18
# 288
# [INFO] elapsed time: 0.11
# 289
# [INFO] elapsed time: 0.18
# 290
# [INFO] elapsed time: 0.10
# 291
# [INFO] elapsed time: 0.10
# 292
# [INFO] elapsed time: 0.20
# 293
# [INFO] elapsed time: 0.09
# 294
# [INFO] elapsed time: 0.10
# 295
# [INFO] elapsed time: 0.08
# 296
# [INFO] elapsed time: 0.12
# 297
# [INFO] elapsed time: 0.10
# 298
# [INFO] elapsed time: 0.07
# 299
# [INFO] elapsed time: 0.12
# 300
# [INFO] elapsed time: 0.08
# 301
# [INFO] elapsed time: 0.07
# 302
# [INFO] elapsed time: 0.14
# 303
# [INFO] elapsed time: 0.08
# 304
# [INFO] elapsed time: 0.08
# 305
# [INFO] elapsed time: 0.12
# 306
# [INFO] elapsed time: 0.06
# 307
# [INFO] elapsed time: 0.16
# 308
# [INFO] elapsed time: 0.09
# 309
# [INFO] elapsed time: 0.15
# 310
# [INFO] elapsed time: 0.10
# 311
# [INFO] elapsed time: 0.06
# 312
# [INFO] elapsed time: 0.22
# 313
# [INFO] elapsed time: 0.15
# 314
# [INFO] elapsed time: 0.76
# 315
# [INFO] elapsed time: 0.47
# 316
# [INFO] elapsed time: 0.28
# 317
# [INFO] elapsed time: 0.36
# 318
# [INFO] elapsed time: 1.03
# 319
# [INFO] elapsed time: 0.30
# 320
# [INFO] elapsed time: 0.10
# 321
# [INFO] elapsed time: 0.19
# 322
# [INFO] elapsed time: 0.09
# 323
# [INFO] elapsed time: 0.15
# 324
# [INFO] elapsed time: 0.08
# 325
# [INFO] elapsed time: 0.10
# 326
# [INFO] elapsed time: 0.09
# 327
# [INFO] elapsed time: 0.09
# 328
# [INFO] elapsed time: 0.19
# 329
# [INFO] elapsed time: 0.09
# 330
# [INFO] elapsed time: 0.24
# 331
# [INFO] elapsed time: 0.09
# 332
# [INFO] elapsed time: 0.12
# 333
# [INFO] elapsed time: 0.09
# 334
# [INFO] elapsed time: 0.10
# 335
# [INFO] elapsed time: 0.12
# 336
# [INFO] elapsed time: 0.08
# 337
# [INFO] elapsed time: 0.16
# 338
# [INFO] elapsed time: 0.10
# 339
# [INFO] elapsed time: 0.28
# 340
# [INFO] elapsed time: 0.07
# 341
# [INFO] elapsed time: 0.10
# 342
# [INFO] elapsed time: 0.09
# 343
# [INFO] elapsed time: 0.13
# 344
# [INFO] elapsed time: 0.11
# 345
# [INFO] elapsed time: 0.10
# 346
# [INFO] elapsed time: 0.22
# 347
# [INFO] elapsed time: 0.08
# 348
# [INFO] elapsed time: 0.08
# 349
# [INFO] elapsed time: 0.09
# 350
# [INFO] elapsed time: 0.08
# 351
# [INFO] elapsed time: 0.21
# 352
# [INFO] elapsed time: 0.06
# 353
# [INFO] elapsed time: 0.05
# 354
# [INFO] elapsed time: 0.21
# 355
# [INFO] elapsed time: 0.06
# 356
# [INFO] elapsed time: 0.06
# 357
# [INFO] elapsed time: 0.23
# 358
# [INFO] elapsed time: 0.06
# 359
# [INFO] elapsed time: 0.19
# 360
# [INFO] elapsed time: 0.08
# 361
# [INFO] elapsed time: 0.07
# 362
# [INFO] elapsed time: 0.20
# 363
# [INFO] elapsed time: 0.05
# 364
# [INFO] elapsed time: 0.07
# 365
# [INFO] elapsed time: 0.08
# 366
# [INFO] elapsed time: 0.07
# 367
# [INFO] elapsed time: 0.06
# 368
# [INFO] elapsed time: 0.22
# 369
# [INFO] elapsed time: 0.07
# 370
# [INFO] elapsed time: 0.36
# 371
# [INFO] elapsed time: 0.06
# 372
# [INFO] elapsed time: 0.10
# 373
# [INFO] elapsed time: 0.07
# 374
# [INFO] elapsed time: 0.07
# 375
# [INFO] elapsed time: 0.15
# 376
# [INFO] elapsed time: 0.06
# 377
# [INFO] elapsed time: 0.06
# 378
# [INFO] elapsed time: 0.10
# 379
# [INFO] elapsed time: 0.10
# 380
# [INFO] elapsed time: 0.10
# 381
# [INFO] elapsed time: 0.10
# 382
# [INFO] elapsed time: 0.09
# 383
# [INFO] elapsed time: 0.08
# 384
# [INFO] elapsed time: 0.21
# 385
# [INFO] elapsed time: 0.07
# 386
# [INFO] elapsed time: 0.08
# 387
# [INFO] elapsed time: 0.18
# 388
# [INFO] elapsed time: 0.06
# 389
# [INFO] elapsed time: 0.08
# 390
# [INFO] elapsed time: 0.26
# 391
# [INFO] elapsed time: 0.08
# 392
# [INFO] elapsed time: 0.17
# 393
# [INFO] elapsed time: 0.19
# 394
# [INFO] elapsed time: 0.08
# 395
# [INFO] elapsed time: 0.08
# 396
# [INFO] elapsed time: 0.07
# 397
# [INFO] elapsed time: 0.10
# 398
# [INFO] elapsed time: 0.13
# 399
# [INFO] elapsed time: 0.47
# 400
# [INFO] elapsed time: 0.08
# [INFO] elapsed time (total): 114.33
# [INFO] approx. FPS: 3.50
