# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function


import argparse
import os
import tempfile
import subprocess
import tensorflow as tf
import numpy as np
import tfimage as im
import threading
import time
import multiprocessing

edge_pool = None


parser = argparse.ArgumentParser()
parser.add_argument("--workers", type=int, default=1, help="number of workers")
parser.add_argument("--pad", action="store_true", help="pad instead of crop for resize operation")
parser.add_argument("--size", type=int, default=256, help="size to use for resize operation")
parser.add_argument("--b_dir", type=str, help="path to folder containing B images for combine operation")
#parser.add_argument("--operation", default="resize", choices=["grayscale", "resize", "blank", "combine", "edges"])
a = parser.parse_known_args()
# Resize original images
'''
pad = "store_true"
size1 = 256
input_dir = "C:/Users/Thiya/Desktop/Wayne/Sofwerx/Project/photos1/original/"
output_dir = "C:/Users/Thiya/Desktop/Wayne/Sofwerx/Project/photos1/original_resized/"
operation = "resize"
'''
'''
# Resize landmark images
pad = "store_true"
size1 = 256
input_dir = "C:/Users/Thiya/Desktop/Wayne/Sofwerx/Project/photos1/landmarks/"
output_dir = "C:/Users/Thiya/Desktop/Wayne/Sofwerx/Project/photos1/landmarks_resized/"
operation = "resize"
'''

# Combine both resized original and landmark images
pad = "store_true"
size1 = 256
input_dir = "C:/Users/Thiya/Desktop/Wayne/Sofwerx/Project/photos1/landmarks_resized/"
output_dir = "C:/Users/Thiya/Desktop/Wayne/Sofwerx/Project/photos1/combined/"
operation = "combine"
b_dir="C:/Users/Thiya/Desktop/Wayne/Sofwerx/Project/photos1/original_resized/"
#parser.add_argument("--input_dir", required=True, default="C:/Users/Thiya/Desktop/Wayne/Sofwerx/Project/photos/original/", help="path to folder containing images")
#parser.add_argument("input_dir", default='C:/Users/Thiya/Desktop/Wayne/Sofwerx/Project/photos/original/', help="path to folder containing images")
#parser.add_argument("--output_dir", required=True, default="C:/Users/Thiya/Desktop/Wayne/Sofwerx/Project/photos/original_resized/",help="output path")

#parser.add_argument("output_dir", default='C:/Users/Thiya/Desktop/Wayne/Sofwerx/Project/photos/original_resized/', help="output path")
#parser.add_argument("operation", default='resize', choices=["grayscale", "resize", "blank", "combine", "edges"])


# combine

#a = parser.parse_args()



def resize(src):
    height, width, _ = src.shape
    dst = src
    if height != width:
        if pad:
            size = max(height, width)
            # pad to correct ratio
            oh = (size - height) // 2
            ow = (size - width) // 2
            dst = im.pad(image=dst, offset_height=oh, offset_width=ow, target_height=size, target_width=size)
        else:
            # crop to correct ratio
            size = min(height, width)
            oh = (height - size) // 2
            ow = (width - size) // 2
            dst = im.crop(image=dst, offset_height=oh, offset_width=ow, target_height=size, target_width=size)

    assert(dst.shape[0] == dst.shape[1])

    size, _, _ = dst.shape
    if size > size1:
        dst = im.downscale(images=dst, size=[size1, size1])
    elif size < size1:
        dst = im.upscale(images=dst, size=[size1, size1])
    return dst


def blank(src):
    height, width, _ = src.shape
    if height != width:
        raise Exception("non-square image")

    image_size = width
    size = int(image_size * 0.3)
    offset = int(image_size / 2 - size / 2)

    dst = src
    dst[offset:offset + size,offset:offset + size,:] = np.ones([size, size, 3])
    return dst


def combine(src, src_path):
    if b_dir is None:
        raise Exception("missing b_dir")

    # find corresponding file in b_dir, could have a different extension
    basename, _ = os.path.splitext(os.path.basename(src_path))
    for ext in [".png", ".jpg"]:
        sibling_path = os.path.join(b_dir, basename + ext)
        if os.path.exists(sibling_path):
            sibling = im.load(sibling_path)
            break
    else:
        raise Exception("could not find sibling image for " + src_path)

    # make sure that dimensions are correct
    height, width, _ = src.shape
    if height != sibling.shape[0] or width != sibling.shape[1]:
        raise Exception("differing sizes")
    
    # convert both images to RGB if necessary
    if src.shape[2] == 1:
        src = im.grayscale_to_rgb(images=src)

    if sibling.shape[2] == 1:
        sibling = im.grayscale_to_rgb(images=sibling)

    # remove alpha channel
    if src.shape[2] == 4:
        src = src[:,:,:3]
    
    if sibling.shape[2] == 4:
        sibling = sibling[:,:,:3]

    return np.concatenate([src, sibling], axis=1)


def grayscale(src):
    return im.grayscale_to_rgb(images=im.rgb_to_grayscale(images=src))


net = None
def run_caffe(src):
    # lazy load caffe and create net
    global net
    if net is None:
        # don't require caffe unless we are doing edge detection
        os.environ["GLOG_minloglevel"] = "2" # disable logging from caffe
        import caffe
        # using this requires using the docker image or assembling a bunch of dependencies
        # and then changing these hardcoded paths
        net = caffe.Net("/opt/caffe/examples/hed/deploy.prototxt", "/opt/caffe/hed_pretrained_bsds.caffemodel", caffe.TEST)
        
    net.blobs["data"].reshape(1, *src.shape)
    net.blobs["data"].data[...] = src
    net.forward()
    return net.blobs["sigmoid-fuse"].data[0][0,:,:]

    
def edges(src):
    # based on https://github.com/phillipi/pix2pix/blob/master/scripts/edges/batch_hed.py
    # and https://github.com/phillipi/pix2pix/blob/master/scripts/edges/PostprocessHED.m
    import scipy.io
    src = src * 255
    border = 128 # put a padding around images since edge detection seems to detect edge of image
    src = src[:,:,:3] # remove alpha channel if present
    src = np.pad(src, ((border, border), (border, border), (0,0)), "reflect")
    src = src[:,:,::-1]
    src -= np.array((104.00698793,116.66876762,122.67891434))
    src = src.transpose((2, 0, 1))

    # [height, width, channels] => [batch, channel, height, width]
    fuse = edge_pool.apply(run_caffe, [src])
    fuse = fuse[border:-border, border:-border]

    with tempfile.NamedTemporaryFile(suffix=".png") as png_file, tempfile.NamedTemporaryFile(suffix=".mat") as mat_file:
        scipy.io.savemat(mat_file.name, {"input": fuse})
        
        octave_code = r"""
E = 1-load(input_path).input;
E = imresize(E, [image_width,image_width]);
E = 1 - E;
E = single(E);
[Ox, Oy] = gradient(convTri(E, 4), 1);
[Oxx, ~] = gradient(Ox, 1);
[Oxy, Oyy] = gradient(Oy, 1);
O = mod(atan(Oyy .* sign(-Oxy) ./ (Oxx + 1e-5)), pi);
E = edgesNmsMex(E, O, 1, 5, 1.01, 1);
E = double(E >= max(eps, threshold));
E = bwmorph(E, 'thin', inf);
E = bwareaopen(E, small_edge);
E = 1 - E;
E = uint8(E * 255);
imwrite(E, output_path);
"""

        config = dict(
            input_path="'%s'" % mat_file.name,
            output_path="'%s'" % png_file.name,
            image_width=256,
            threshold=25.0/255.0,
            small_edge=5,
        )

        args = ["octave"]
        for k, v in config.items():
            args.extend(["--eval", "%s=%s;" % (k, v)])

        args.extend(["--eval", octave_code])
        try:
            subprocess.check_output(args, stderr=subprocess.STDOUT)
        except subprocess.CalledProcessError as e:
            print("octave failed")
            print("returncode:", e.returncode)
            print("output:", e.output)
            raise
        return im.load(png_file.name)


def process(src_path, dst_path):
    
    src = im.load(src_path)

    if operation == "grayscale":
        dst = grayscale(src)
    elif operation == "resize":
        dst = resize(src)
    elif operation == "blank":
        dst = blank(src)
    elif operation == "combine":
        dst = combine(src, src_path)
    elif operation == "edges":
        dst = edges(src)
    else:
        raise Exception("invalid operation")

    im.save(dst, dst_path)


complete_lock = threading.Lock()
start = None
num_complete = 0
total = 0

def complete():
    global num_complete, rate, last_complete

    with complete_lock:
        num_complete += 1
        now = time.time()
        elapsed = now - start
        rate = num_complete / elapsed
        if rate > 0:
            remaining = (total - num_complete) / rate
        else:
            remaining = 0

        print("%d/%d complete  %0.2f images/sec  %dm%ds elapsed  %dm%ds remaining" % (num_complete, total, rate, elapsed // 60, elapsed % 60, remaining // 60, remaining % 60))

        last_complete = now


def main():

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    src_paths = []
    dst_paths = []

    skipped = 0
    for src_path in im.find(input_dir):
        name, _ = os.path.splitext(os.path.basename(src_path))
        dst_path = os.path.join(output_dir, name + ".png")
        if os.path.exists(dst_path):
            skipped += 1
        else:
            src_paths.append(src_path)
            dst_paths.append(dst_path)
    
    print("skipping %d files that already exist" % skipped)
            
    global total
    total = len(src_paths)
    
    print("processing %d files" % total)

    global start
    start = time.time()
    operation = "resize"
    if operation == "edges":
        # use a multiprocessing pool for this operation so it can use multiple CPUs
        # create the pool before we launch processing threads
        global edge_pool
        edge_pool = multiprocessing.Pool(a.workers)
    workers = 1
    if workers == 1:
        with tf.Session() as sess:
            for src_path, dst_path in zip(src_paths, dst_paths):
                process(src_path, dst_path)
                complete()
    else:
        queue = tf.train.input_producer(zip(src_paths, dst_paths), shuffle=False, num_epochs=1)
        dequeue_op = queue.dequeue()

        def worker(coord):
            with sess.as_default():
                while not coord.should_stop():
                    try:
                        src_path, dst_path = sess.run(dequeue_op)
                    except tf.errors.OutOfRangeError:
                        coord.request_stop()
                        break

                    process(src_path, dst_path)
                    complete()

        # init epoch counter for the queue
        local_init_op = tf.local_variables_initializer()
        with tf.Session() as sess:
            sess.run(local_init_op)

            coord = tf.train.Coordinator()
            threads = tf.train.start_queue_runners(coord=coord)
            for i in range(a.workers):
                t = threading.Thread(target=worker, args=(coord,))
                t.start()
                threads.append(t)
            
            try:
                coord.join(threads)
            except KeyboardInterrupt:
                coord.request_stop()
                coord.join(threads)

main()
# Out:
# skipping 0 files that already exist
# processing 500 files
# 1/500 complete  16.14 images/sec  0m0s elapsed  0m30s remaining
# 2/500 complete  20.22 images/sec  0m0s elapsed  0m24s remaining
# 3/500 complete  22.92 images/sec  0m0s elapsed  0m21s remaining
# 4/500 complete  24.71 images/sec  0m0s elapsed  0m20s remaining
# 5/500 complete  25.40 images/sec  0m0s elapsed  0m19s remaining
# 6/500 complete  26.00 images/sec  0m0s elapsed  0m19s remaining
# 7/500 complete  26.14 images/sec  0m0s elapsed  0m18s remaining
# 8/500 complete  26.60 images/sec  0m0s elapsed  0m18s remaining
# 9/500 complete  27.13 images/sec  0m0s elapsed  0m18s remaining
# 10/500 complete  27.65 images/sec  0m0s elapsed  0m17s remaining
# 11/500 complete  28.09 images/sec  0m0s elapsed  0m17s remaining
# 12/500 complete  28.06 images/sec  0m0s elapsed  0m17s remaining
# 13/500 complete  27.92 images/sec  0m0s elapsed  0m17s remaining
# 14/500 complete  28.08 images/sec  0m0s elapsed  0m17s remaining
# 15/500 complete  28.27 images/sec  0m0s elapsed  0m17s remaining
# 16/500 complete  28.45 images/sec  0m0s elapsed  0m17s remaining
# 17/500 complete  28.64 images/sec  0m0s elapsed  0m16s remaining
# 18/500 complete  28.73 images/sec  0m0s elapsed  0m16s remaining
# 19/500 complete  28.81 images/sec  0m0s elapsed  0m16s remaining
# 20/500 complete  28.35 images/sec  0m0s elapsed  0m16s remaining
# 21/500 complete  28.56 images/sec  0m0s elapsed  0m16s remaining
# 22/500 complete  27.15 images/sec  0m0s elapsed  0m17s remaining
# 23/500 complete  26.64 images/sec  0m0s elapsed  0m17s remaining
# 24/500 complete  26.48 images/sec  0m0s elapsed  0m17s remaining
# 25/500 complete  26.34 images/sec  0m0s elapsed  0m18s remaining
# 26/500 complete  25.79 images/sec  0m1s elapsed  0m18s remaining
# 27/500 complete  25.12 images/sec  0m1s elapsed  0m18s remaining
# 28/500 complete  24.80 images/sec  0m1s elapsed  0m19s remaining
# 29/500 complete  24.64 images/sec  0m1s elapsed  0m19s remaining
# 30/500 complete  24.41 images/sec  0m1s elapsed  0m19s remaining
# 31/500 complete  23.89 images/sec  0m1s elapsed  0m19s remaining
# 32/500 complete  23.65 images/sec  0m1s elapsed  0m19s remaining
# 33/500 complete  22.89 images/sec  0m1s elapsed  0m20s remaining
# 34/500 complete  22.79 images/sec  0m1s elapsed  0m20s remaining
# 35/500 complete  22.69 images/sec  0m1s elapsed  0m20s remaining
# 36/500 complete  22.65 images/sec  0m1s elapsed  0m20s remaining
# 37/500 complete  22.67 images/sec  0m1s elapsed  0m20s remaining
# 38/500 complete  22.74 images/sec  0m1s elapsed  0m20s remaining
# 39/500 complete  22.74 images/sec  0m1s elapsed  0m20s remaining
# 40/500 complete  22.81 images/sec  0m1s elapsed  0m20s remaining
# 41/500 complete  22.91 images/sec  0m1s elapsed  0m20s remaining
# 42/500 complete  23.00 images/sec  0m1s elapsed  0m19s remaining
# 43/500 complete  23.03 images/sec  0m1s elapsed  0m19s remaining
# 44/500 complete  23.12 images/sec  0m1s elapsed  0m19s remaining
# 45/500 complete  23.25 images/sec  0m1s elapsed  0m19s remaining
# 46/500 complete  23.37 images/sec  0m1s elapsed  0m19s remaining
# 47/500 complete  23.47 images/sec  0m2s elapsed  0m19s remaining
# 48/500 complete  23.43 images/sec  0m2s elapsed  0m19s remaining
# 49/500 complete  23.52 images/sec  0m2s elapsed  0m19s remaining
# 50/500 complete  23.60 images/sec  0m2s elapsed  0m19s remaining
# 51/500 complete  23.65 images/sec  0m2s elapsed  0m18s remaining
# 52/500 complete  23.75 images/sec  0m2s elapsed  0m18s remaining
# 53/500 complete  23.75 images/sec  0m2s elapsed  0m18s remaining
# 54/500 complete  23.84 images/sec  0m2s elapsed  0m18s remaining
# 55/500 complete  23.85 images/sec  0m2s elapsed  0m18s remaining
# 56/500 complete  23.86 images/sec  0m2s elapsed  0m18s remaining
# 57/500 complete  23.98 images/sec  0m2s elapsed  0m18s remaining
# 58/500 complete  23.99 images/sec  0m2s elapsed  0m18s remaining
# 59/500 complete  23.94 images/sec  0m2s elapsed  0m18s remaining
# 60/500 complete  23.98 images/sec  0m2s elapsed  0m18s remaining
# 61/500 complete  24.02 images/sec  0m2s elapsed  0m18s remaining
# 62/500 complete  23.96 images/sec  0m2s elapsed  0m18s remaining
# 63/500 complete  23.86 images/sec  0m2s elapsed  0m18s remaining
# 64/500 complete  23.87 images/sec  0m2s elapsed  0m18s remaining
# 65/500 complete  23.85 images/sec  0m2s elapsed  0m18s remaining
# 66/500 complete  23.81 images/sec  0m2s elapsed  0m18s remaining
# 67/500 complete  23.65 images/sec  0m2s elapsed  0m18s remaining
# 68/500 complete  23.55 images/sec  0m2s elapsed  0m18s remaining
# 69/500 complete  23.54 images/sec  0m2s elapsed  0m18s remaining
# 70/500 complete  23.55 images/sec  0m2s elapsed  0m18s remaining
# 71/500 complete  23.38 images/sec  0m3s elapsed  0m18s remaining
# 72/500 complete  23.23 images/sec  0m3s elapsed  0m18s remaining
# 73/500 complete  23.12 images/sec  0m3s elapsed  0m18s remaining
# 74/500 complete  23.07 images/sec  0m3s elapsed  0m18s remaining
# 75/500 complete  23.02 images/sec  0m3s elapsed  0m18s remaining
# 76/500 complete  22.88 images/sec  0m3s elapsed  0m18s remaining
# 77/500 complete  22.47 images/sec  0m3s elapsed  0m18s remaining
# 78/500 complete  22.14 images/sec  0m3s elapsed  0m19s remaining
# 79/500 complete  21.99 images/sec  0m3s elapsed  0m19s remaining
# 80/500 complete  21.84 images/sec  0m3s elapsed  0m19s remaining
# 81/500 complete  21.74 images/sec  0m3s elapsed  0m19s remaining
# 82/500 complete  21.68 images/sec  0m3s elapsed  0m19s remaining
# 83/500 complete  21.61 images/sec  0m3s elapsed  0m19s remaining
# 84/500 complete  21.43 images/sec  0m3s elapsed  0m19s remaining
# 85/500 complete  21.35 images/sec  0m3s elapsed  0m19s remaining
# 86/500 complete  21.17 images/sec  0m4s elapsed  0m19s remaining
# 87/500 complete  20.67 images/sec  0m4s elapsed  0m19s remaining
# 88/500 complete  20.47 images/sec  0m4s elapsed  0m20s remaining
# 89/500 complete  20.38 images/sec  0m4s elapsed  0m20s remaining
# 90/500 complete  20.32 images/sec  0m4s elapsed  0m20s remaining
# 91/500 complete  20.28 images/sec  0m4s elapsed  0m20s remaining
# 92/500 complete  20.15 images/sec  0m4s elapsed  0m20s remaining
# 93/500 complete  20.13 images/sec  0m4s elapsed  0m20s remaining
# 94/500 complete  20.05 images/sec  0m4s elapsed  0m20s remaining
# 95/500 complete  19.94 images/sec  0m4s elapsed  0m20s remaining
# 96/500 complete  19.91 images/sec  0m4s elapsed  0m20s remaining
# 97/500 complete  19.83 images/sec  0m4s elapsed  0m20s remaining
# 98/500 complete  19.76 images/sec  0m4s elapsed  0m20s remaining
# 99/500 complete  19.73 images/sec  0m5s elapsed  0m20s remaining
# 100/500 complete  19.59 images/sec  0m5s elapsed  0m20s remaining
# 101/500 complete  19.57 images/sec  0m5s elapsed  0m20s remaining
# 102/500 complete  19.56 images/sec  0m5s elapsed  0m20s remaining
# 103/500 complete  19.55 images/sec  0m5s elapsed  0m20s remaining
# 104/500 complete  19.54 images/sec  0m5s elapsed  0m20s remaining
# 105/500 complete  19.53 images/sec  0m5s elapsed  0m20s remaining
# 106/500 complete  19.47 images/sec  0m5s elapsed  0m20s remaining
# 107/500 complete  19.37 images/sec  0m5s elapsed  0m20s remaining
# 108/500 complete  19.34 images/sec  0m5s elapsed  0m20s remaining
# 109/500 complete  19.32 images/sec  0m5s elapsed  0m20s remaining
# 110/500 complete  19.30 images/sec  0m5s elapsed  0m20s remaining
# 111/500 complete  19.25 images/sec  0m5s elapsed  0m20s remaining
# 112/500 complete  19.22 images/sec  0m5s elapsed  0m20s remaining
# 113/500 complete  19.20 images/sec  0m5s elapsed  0m20s remaining
# 114/500 complete  19.19 images/sec  0m5s elapsed  0m20s remaining
# 115/500 complete  19.18 images/sec  0m5s elapsed  0m20s remaining
# 116/500 complete  19.06 images/sec  0m6s elapsed  0m20s remaining
# 117/500 complete  18.85 images/sec  0m6s elapsed  0m20s remaining
# 118/500 complete  18.85 images/sec  0m6s elapsed  0m20s remaining
# 119/500 complete  18.85 images/sec  0m6s elapsed  0m20s remaining
# 120/500 complete  18.86 images/sec  0m6s elapsed  0m20s remaining
# 121/500 complete  18.88 images/sec  0m6s elapsed  0m20s remaining
# 122/500 complete  18.91 images/sec  0m6s elapsed  0m19s remaining
# 123/500 complete  18.95 images/sec  0m6s elapsed  0m19s remaining
# 124/500 complete  19.02 images/sec  0m6s elapsed  0m19s remaining
# 125/500 complete  19.03 images/sec  0m6s elapsed  0m19s remaining
# 126/500 complete  19.07 images/sec  0m6s elapsed  0m19s remaining
# 127/500 complete  19.07 images/sec  0m6s elapsed  0m19s remaining
# 128/500 complete  19.11 images/sec  0m6s elapsed  0m19s remaining
# 129/500 complete  19.13 images/sec  0m6s elapsed  0m19s remaining
# 130/500 complete  19.11 images/sec  0m6s elapsed  0m19s remaining
# 131/500 complete  19.10 images/sec  0m6s elapsed  0m19s remaining
# 132/500 complete  19.03 images/sec  0m6s elapsed  0m19s remaining
# 133/500 complete  19.02 images/sec  0m6s elapsed  0m19s remaining
# 134/500 complete  19.04 images/sec  0m7s elapsed  0m19s remaining
# 135/500 complete  19.08 images/sec  0m7s elapsed  0m19s remaining
# 136/500 complete  19.12 images/sec  0m7s elapsed  0m19s remaining
# 137/500 complete  19.12 images/sec  0m7s elapsed  0m18s remaining
# 138/500 complete  19.16 images/sec  0m7s elapsed  0m18s remaining
# 139/500 complete  19.19 images/sec  0m7s elapsed  0m18s remaining
# 140/500 complete  19.14 images/sec  0m7s elapsed  0m18s remaining
# 141/500 complete  19.17 images/sec  0m7s elapsed  0m18s remaining
# 142/500 complete  19.20 images/sec  0m7s elapsed  0m18s remaining
# 143/500 complete  19.24 images/sec  0m7s elapsed  0m18s remaining
# 144/500 complete  19.29 images/sec  0m7s elapsed  0m18s remaining
# 145/500 complete  19.33 images/sec  0m7s elapsed  0m18s remaining
# 146/500 complete  19.37 images/sec  0m7s elapsed  0m18s remaining
# 147/500 complete  19.42 images/sec  0m7s elapsed  0m18s remaining
# 148/500 complete  19.47 images/sec  0m7s elapsed  0m18s remaining
# 149/500 complete  19.51 images/sec  0m7s elapsed  0m17s remaining
# 150/500 complete  19.56 images/sec  0m7s elapsed  0m17s remaining
# 151/500 complete  19.61 images/sec  0m7s elapsed  0m17s remaining
# 152/500 complete  19.62 images/sec  0m7s elapsed  0m17s remaining
# 153/500 complete  19.63 images/sec  0m7s elapsed  0m17s remaining
# 154/500 complete  19.62 images/sec  0m7s elapsed  0m17s remaining
# 155/500 complete  19.58 images/sec  0m7s elapsed  0m17s remaining
# 156/500 complete  19.60 images/sec  0m7s elapsed  0m17s remaining
# 157/500 complete  19.60 images/sec  0m8s elapsed  0m17s remaining
# 158/500 complete  19.62 images/sec  0m8s elapsed  0m17s remaining
# 159/500 complete  19.63 images/sec  0m8s elapsed  0m17s remaining
# 160/500 complete  19.63 images/sec  0m8s elapsed  0m17s remaining
# 161/500 complete  19.62 images/sec  0m8s elapsed  0m17s remaining
# 162/500 complete  19.57 images/sec  0m8s elapsed  0m17s remaining
# 163/500 complete  19.59 images/sec  0m8s elapsed  0m17s remaining
# 164/500 complete  19.61 images/sec  0m8s elapsed  0m17s remaining
# 165/500 complete  19.63 images/sec  0m8s elapsed  0m17s remaining
# 166/500 complete  19.63 images/sec  0m8s elapsed  0m17s remaining
# 167/500 complete  19.66 images/sec  0m8s elapsed  0m16s remaining
# 168/500 complete  19.68 images/sec  0m8s elapsed  0m16s remaining
# 169/500 complete  19.72 images/sec  0m8s elapsed  0m16s remaining
# 170/500 complete  19.74 images/sec  0m8s elapsed  0m16s remaining
# 171/500 complete  19.77 images/sec  0m8s elapsed  0m16s remaining
# 172/500 complete  19.81 images/sec  0m8s elapsed  0m16s remaining
# 173/500 complete  19.85 images/sec  0m8s elapsed  0m16s remaining
# 174/500 complete  19.89 images/sec  0m8s elapsed  0m16s remaining
# 175/500 complete  19.79 images/sec  0m8s elapsed  0m16s remaining
# 176/500 complete  19.65 images/sec  0m8s elapsed  0m16s remaining
# 177/500 complete  19.52 images/sec  0m9s elapsed  0m16s remaining
# 178/500 complete  19.51 images/sec  0m9s elapsed  0m16s remaining
# 179/500 complete  19.49 images/sec  0m9s elapsed  0m16s remaining
# 180/500 complete  19.48 images/sec  0m9s elapsed  0m16s remaining
# 181/500 complete  19.45 images/sec  0m9s elapsed  0m16s remaining
# 182/500 complete  19.44 images/sec  0m9s elapsed  0m16s remaining
# 183/500 complete  19.43 images/sec  0m9s elapsed  0m16s remaining
# 184/500 complete  19.34 images/sec  0m9s elapsed  0m16s remaining
# 185/500 complete  19.17 images/sec  0m9s elapsed  0m16s remaining
# 186/500 complete  19.12 images/sec  0m9s elapsed  0m16s remaining
# 187/500 complete  19.10 images/sec  0m9s elapsed  0m16s remaining
# 188/500 complete  19.08 images/sec  0m9s elapsed  0m16s remaining
# 189/500 complete  19.08 images/sec  0m9s elapsed  0m16s remaining
# 190/500 complete  19.08 images/sec  0m9s elapsed  0m16s remaining
# 191/500 complete  19.07 images/sec  0m10s elapsed  0m16s remaining
# 192/500 complete  19.06 images/sec  0m10s elapsed  0m16s remaining
# 193/500 complete  19.05 images/sec  0m10s elapsed  0m16s remaining
# 194/500 complete  19.03 images/sec  0m10s elapsed  0m16s remaining
# 195/500 complete  19.02 images/sec  0m10s elapsed  0m16s remaining
# 196/500 complete  19.02 images/sec  0m10s elapsed  0m15s remaining
# 197/500 complete  19.01 images/sec  0m10s elapsed  0m15s remaining
# 198/500 complete  19.00 images/sec  0m10s elapsed  0m15s remaining
# 199/500 complete  18.98 images/sec  0m10s elapsed  0m15s remaining
# 200/500 complete  18.97 images/sec  0m10s elapsed  0m15s remaining
# 201/500 complete  18.94 images/sec  0m10s elapsed  0m15s remaining
# 202/500 complete  18.93 images/sec  0m10s elapsed  0m15s remaining
# 203/500 complete  18.92 images/sec  0m10s elapsed  0m15s remaining
# 204/500 complete  18.90 images/sec  0m10s elapsed  0m15s remaining
# 205/500 complete  18.80 images/sec  0m10s elapsed  0m15s remaining
# 206/500 complete  18.73 images/sec  0m11s elapsed  0m15s remaining
# 207/500 complete  18.68 images/sec  0m11s elapsed  0m15s remaining
# 208/500 complete  18.63 images/sec  0m11s elapsed  0m15s remaining
# 209/500 complete  18.63 images/sec  0m11s elapsed  0m15s remaining
# 210/500 complete  18.62 images/sec  0m11s elapsed  0m15s remaining
# 211/500 complete  18.62 images/sec  0m11s elapsed  0m15s remaining
# 212/500 complete  18.62 images/sec  0m11s elapsed  0m15s remaining
# 213/500 complete  18.62 images/sec  0m11s elapsed  0m15s remaining
# 214/500 complete  18.61 images/sec  0m11s elapsed  0m15s remaining
# 215/500 complete  18.56 images/sec  0m11s elapsed  0m15s remaining
# 216/500 complete  18.51 images/sec  0m11s elapsed  0m15s remaining
# 217/500 complete  18.48 images/sec  0m11s elapsed  0m15s remaining
# 218/500 complete  18.45 images/sec  0m11s elapsed  0m15s remaining
# 219/500 complete  18.43 images/sec  0m11s elapsed  0m15s remaining
# 220/500 complete  18.42 images/sec  0m11s elapsed  0m15s remaining
# 221/500 complete  18.40 images/sec  0m12s elapsed  0m15s remaining
# 222/500 complete  18.37 images/sec  0m12s elapsed  0m15s remaining
# 223/500 complete  18.34 images/sec  0m12s elapsed  0m15s remaining
# 224/500 complete  18.30 images/sec  0m12s elapsed  0m15s remaining
# 225/500 complete  18.22 images/sec  0m12s elapsed  0m15s remaining
# 226/500 complete  18.06 images/sec  0m12s elapsed  0m15s remaining
# 227/500 complete  18.00 images/sec  0m12s elapsed  0m15s remaining
# 228/500 complete  18.00 images/sec  0m12s elapsed  0m15s remaining
# 229/500 complete  18.00 images/sec  0m12s elapsed  0m15s remaining
# 230/500 complete  17.99 images/sec  0m12s elapsed  0m15s remaining
# 231/500 complete  17.97 images/sec  0m12s elapsed  0m14s remaining
# 232/500 complete  17.90 images/sec  0m12s elapsed  0m14s remaining
# 233/500 complete  17.86 images/sec  0m13s elapsed  0m14s remaining
# 234/500 complete  17.86 images/sec  0m13s elapsed  0m14s remaining
# 235/500 complete  17.84 images/sec  0m13s elapsed  0m14s remaining
# 236/500 complete  17.85 images/sec  0m13s elapsed  0m14s remaining
# 237/500 complete  17.84 images/sec  0m13s elapsed  0m14s remaining
# 238/500 complete  17.83 images/sec  0m13s elapsed  0m14s remaining
# 239/500 complete  17.84 images/sec  0m13s elapsed  0m14s remaining
# 240/500 complete  17.84 images/sec  0m13s elapsed  0m14s remaining
# 241/500 complete  17.77 images/sec  0m13s elapsed  0m14s remaining
# 242/500 complete  17.72 images/sec  0m13s elapsed  0m14s remaining
# 243/500 complete  17.62 images/sec  0m13s elapsed  0m14s remaining
# 244/500 complete  17.58 images/sec  0m13s elapsed  0m14s remaining
# 245/500 complete  17.57 images/sec  0m13s elapsed  0m14s remaining
# 246/500 complete  17.50 images/sec  0m14s elapsed  0m14s remaining
# 247/500 complete  17.51 images/sec  0m14s elapsed  0m14s remaining
# 248/500 complete  17.51 images/sec  0m14s elapsed  0m14s remaining
# 249/500 complete  17.51 images/sec  0m14s elapsed  0m14s remaining
# 250/500 complete  17.51 images/sec  0m14s elapsed  0m14s remaining
# 251/500 complete  17.48 images/sec  0m14s elapsed  0m14s remaining
# 252/500 complete  17.41 images/sec  0m14s elapsed  0m14s remaining
# 253/500 complete  17.34 images/sec  0m14s elapsed  0m14s remaining
# 254/500 complete  17.34 images/sec  0m14s elapsed  0m14s remaining
# 255/500 complete  17.35 images/sec  0m14s elapsed  0m14s remaining
# 256/500 complete  17.35 images/sec  0m14s elapsed  0m14s remaining
# 257/500 complete  17.35 images/sec  0m14s elapsed  0m14s remaining
# 258/500 complete  17.35 images/sec  0m14s elapsed  0m13s remaining
# 259/500 complete  17.35 images/sec  0m14s elapsed  0m13s remaining
# 260/500 complete  17.35 images/sec  0m14s elapsed  0m13s remaining
# 261/500 complete  17.35 images/sec  0m15s elapsed  0m13s remaining
# 262/500 complete  17.28 images/sec  0m15s elapsed  0m13s remaining
# 263/500 complete  17.26 images/sec  0m15s elapsed  0m13s remaining
# 264/500 complete  17.25 images/sec  0m15s elapsed  0m13s remaining
# 265/500 complete  17.25 images/sec  0m15s elapsed  0m13s remaining
# 266/500 complete  17.25 images/sec  0m15s elapsed  0m13s remaining
# 267/500 complete  17.25 images/sec  0m15s elapsed  0m13s remaining
# 268/500 complete  17.26 images/sec  0m15s elapsed  0m13s remaining
# 269/500 complete  17.26 images/sec  0m15s elapsed  0m13s remaining
# 270/500 complete  17.25 images/sec  0m15s elapsed  0m13s remaining
# 271/500 complete  17.27 images/sec  0m15s elapsed  0m13s remaining
# 272/500 complete  17.28 images/sec  0m15s elapsed  0m13s remaining
# 273/500 complete  17.28 images/sec  0m15s elapsed  0m13s remaining
# 274/500 complete  17.28 images/sec  0m15s elapsed  0m13s remaining
# 275/500 complete  17.30 images/sec  0m15s elapsed  0m13s remaining
# 276/500 complete  17.31 images/sec  0m15s elapsed  0m12s remaining
# 277/500 complete  17.32 images/sec  0m15s elapsed  0m12s remaining
# 278/500 complete  17.33 images/sec  0m16s elapsed  0m12s remaining
# 279/500 complete  17.35 images/sec  0m16s elapsed  0m12s remaining
# 280/500 complete  17.35 images/sec  0m16s elapsed  0m12s remaining
# 281/500 complete  17.35 images/sec  0m16s elapsed  0m12s remaining
# 282/500 complete  17.36 images/sec  0m16s elapsed  0m12s remaining
# 283/500 complete  17.35 images/sec  0m16s elapsed  0m12s remaining
# 284/500 complete  17.35 images/sec  0m16s elapsed  0m12s remaining
# 285/500 complete  17.33 images/sec  0m16s elapsed  0m12s remaining
# 286/500 complete  17.33 images/sec  0m16s elapsed  0m12s remaining
# 287/500 complete  17.33 images/sec  0m16s elapsed  0m12s remaining
# 288/500 complete  17.34 images/sec  0m16s elapsed  0m12s remaining
# 289/500 complete  17.32 images/sec  0m16s elapsed  0m12s remaining
# 290/500 complete  17.32 images/sec  0m16s elapsed  0m12s remaining
# 291/500 complete  17.29 images/sec  0m16s elapsed  0m12s remaining
# 292/500 complete  17.30 images/sec  0m16s elapsed  0m12s remaining
# 293/500 complete  17.30 images/sec  0m16s elapsed  0m11s remaining
# 294/500 complete  17.27 images/sec  0m17s elapsed  0m11s remaining
# 295/500 complete  17.19 images/sec  0m17s elapsed  0m11s remaining
# 296/500 complete  17.17 images/sec  0m17s elapsed  0m11s remaining
# 297/500 complete  17.17 images/sec  0m17s elapsed  0m11s remaining
# 298/500 complete  17.18 images/sec  0m17s elapsed  0m11s remaining
# 299/500 complete  17.18 images/sec  0m17s elapsed  0m11s remaining
# 300/500 complete  17.19 images/sec  0m17s elapsed  0m11s remaining
# 301/500 complete  17.19 images/sec  0m17s elapsed  0m11s remaining
# 302/500 complete  17.20 images/sec  0m17s elapsed  0m11s remaining
# 303/500 complete  17.20 images/sec  0m17s elapsed  0m11s remaining
# 304/500 complete  17.21 images/sec  0m17s elapsed  0m11s remaining
# 305/500 complete  17.16 images/sec  0m17s elapsed  0m11s remaining
# 306/500 complete  17.09 images/sec  0m17s elapsed  0m11s remaining
# 307/500 complete  17.07 images/sec  0m17s elapsed  0m11s remaining
# 308/500 complete  17.07 images/sec  0m18s elapsed  0m11s remaining
# 309/500 complete  17.07 images/sec  0m18s elapsed  0m11s remaining
# 310/500 complete  17.07 images/sec  0m18s elapsed  0m11s remaining
# 311/500 complete  17.08 images/sec  0m18s elapsed  0m11s remaining
# 312/500 complete  17.08 images/sec  0m18s elapsed  0m11s remaining
# 313/500 complete  17.09 images/sec  0m18s elapsed  0m10s remaining
# 314/500 complete  17.10 images/sec  0m18s elapsed  0m10s remaining
# 315/500 complete  17.11 images/sec  0m18s elapsed  0m10s remaining
# 316/500 complete  17.12 images/sec  0m18s elapsed  0m10s remaining
# 317/500 complete  17.13 images/sec  0m18s elapsed  0m10s remaining
# 318/500 complete  17.13 images/sec  0m18s elapsed  0m10s remaining
# 319/500 complete  17.14 images/sec  0m18s elapsed  0m10s remaining
# 320/500 complete  17.15 images/sec  0m18s elapsed  0m10s remaining
# 321/500 complete  17.16 images/sec  0m18s elapsed  0m10s remaining
# 322/500 complete  17.16 images/sec  0m18s elapsed  0m10s remaining
# 323/500 complete  17.17 images/sec  0m18s elapsed  0m10s remaining
# 324/500 complete  17.18 images/sec  0m18s elapsed  0m10s remaining
# 325/500 complete  17.19 images/sec  0m18s elapsed  0m10s remaining
# 326/500 complete  17.19 images/sec  0m18s elapsed  0m10s remaining
# 327/500 complete  17.19 images/sec  0m19s elapsed  0m10s remaining
# 328/500 complete  17.20 images/sec  0m19s elapsed  0m10s remaining
# 329/500 complete  17.21 images/sec  0m19s elapsed  0m9s remaining
# 330/500 complete  17.22 images/sec  0m19s elapsed  0m9s remaining
# 331/500 complete  17.23 images/sec  0m19s elapsed  0m9s remaining
# 332/500 complete  17.24 images/sec  0m19s elapsed  0m9s remaining
# 333/500 complete  17.25 images/sec  0m19s elapsed  0m9s remaining
# 334/500 complete  17.27 images/sec  0m19s elapsed  0m9s remaining
# 335/500 complete  17.29 images/sec  0m19s elapsed  0m9s remaining
# 336/500 complete  17.30 images/sec  0m19s elapsed  0m9s remaining
# 337/500 complete  17.31 images/sec  0m19s elapsed  0m9s remaining
# 338/500 complete  17.33 images/sec  0m19s elapsed  0m9s remaining
# 339/500 complete  17.35 images/sec  0m19s elapsed  0m9s remaining
# 340/500 complete  17.37 images/sec  0m19s elapsed  0m9s remaining
# 341/500 complete  17.35 images/sec  0m19s elapsed  0m9s remaining
# 342/500 complete  17.36 images/sec  0m19s elapsed  0m9s remaining
# 343/500 complete  17.37 images/sec  0m19s elapsed  0m9s remaining
# 344/500 complete  17.29 images/sec  0m19s elapsed  0m9s remaining
# 345/500 complete  17.30 images/sec  0m19s elapsed  0m8s remaining
# 346/500 complete  17.31 images/sec  0m19s elapsed  0m8s remaining
# 347/500 complete  17.32 images/sec  0m20s elapsed  0m8s remaining
# 348/500 complete  17.33 images/sec  0m20s elapsed  0m8s remaining
# 349/500 complete  17.33 images/sec  0m20s elapsed  0m8s remaining
# 350/500 complete  17.34 images/sec  0m20s elapsed  0m8s remaining
# 351/500 complete  17.36 images/sec  0m20s elapsed  0m8s remaining
# 352/500 complete  17.36 images/sec  0m20s elapsed  0m8s remaining
# 353/500 complete  17.36 images/sec  0m20s elapsed  0m8s remaining
# 354/500 complete  17.37 images/sec  0m20s elapsed  0m8s remaining
# 355/500 complete  17.38 images/sec  0m20s elapsed  0m8s remaining
# 356/500 complete  17.39 images/sec  0m20s elapsed  0m8s remaining
# 357/500 complete  17.39 images/sec  0m20s elapsed  0m8s remaining
# 358/500 complete  17.33 images/sec  0m20s elapsed  0m8s remaining
# 359/500 complete  17.21 images/sec  0m20s elapsed  0m8s remaining
# 360/500 complete  17.21 images/sec  0m20s elapsed  0m8s remaining
# 361/500 complete  17.21 images/sec  0m20s elapsed  0m8s remaining
# 362/500 complete  17.22 images/sec  0m21s elapsed  0m8s remaining
# 363/500 complete  17.22 images/sec  0m21s elapsed  0m7s remaining
# 364/500 complete  17.22 images/sec  0m21s elapsed  0m7s remaining
# 365/500 complete  17.23 images/sec  0m21s elapsed  0m7s remaining
# 366/500 complete  17.24 images/sec  0m21s elapsed  0m7s remaining
# 367/500 complete  17.26 images/sec  0m21s elapsed  0m7s remaining
# 368/500 complete  17.28 images/sec  0m21s elapsed  0m7s remaining
# 369/500 complete  17.29 images/sec  0m21s elapsed  0m7s remaining
# 370/500 complete  17.30 images/sec  0m21s elapsed  0m7s remaining
# 371/500 complete  17.32 images/sec  0m21s elapsed  0m7s remaining
# 372/500 complete  17.33 images/sec  0m21s elapsed  0m7s remaining
# 373/500 complete  17.35 images/sec  0m21s elapsed  0m7s remaining
# 374/500 complete  17.35 images/sec  0m21s elapsed  0m7s remaining
# 375/500 complete  17.36 images/sec  0m21s elapsed  0m7s remaining
# 376/500 complete  17.38 images/sec  0m21s elapsed  0m7s remaining
# 377/500 complete  17.40 images/sec  0m21s elapsed  0m7s remaining
# 378/500 complete  17.41 images/sec  0m21s elapsed  0m7s remaining
# 379/500 complete  17.41 images/sec  0m21s elapsed  0m6s remaining
# 380/500 complete  17.41 images/sec  0m21s elapsed  0m6s remaining
# 381/500 complete  17.42 images/sec  0m21s elapsed  0m6s remaining
# 382/500 complete  17.43 images/sec  0m21s elapsed  0m6s remaining
# 383/500 complete  17.44 images/sec  0m21s elapsed  0m6s remaining
# 384/500 complete  17.46 images/sec  0m21s elapsed  0m6s remaining
# 385/500 complete  17.47 images/sec  0m22s elapsed  0m6s remaining
# 386/500 complete  17.48 images/sec  0m22s elapsed  0m6s remaining
# 387/500 complete  17.49 images/sec  0m22s elapsed  0m6s remaining
# 388/500 complete  17.50 images/sec  0m22s elapsed  0m6s remaining
# 389/500 complete  17.51 images/sec  0m22s elapsed  0m6s remaining
# 390/500 complete  17.52 images/sec  0m22s elapsed  0m6s remaining
# 391/500 complete  17.54 images/sec  0m22s elapsed  0m6s remaining
# 392/500 complete  17.55 images/sec  0m22s elapsed  0m6s remaining
# 393/500 complete  17.57 images/sec  0m22s elapsed  0m6s remaining
# 394/500 complete  17.58 images/sec  0m22s elapsed  0m6s remaining
# 395/500 complete  17.60 images/sec  0m22s elapsed  0m5s remaining
# 396/500 complete  17.60 images/sec  0m22s elapsed  0m5s remaining
# 397/500 complete  17.60 images/sec  0m22s elapsed  0m5s remaining
# 398/500 complete  17.55 images/sec  0m22s elapsed  0m5s remaining
# 399/500 complete  17.56 images/sec  0m22s elapsed  0m5s remaining
# 400/500 complete  17.56 images/sec  0m22s elapsed  0m5s remaining
# 401/500 complete  17.57 images/sec  0m22s elapsed  0m5s remaining
# 402/500 complete  17.59 images/sec  0m22s elapsed  0m5s remaining
# 403/500 complete  17.60 images/sec  0m22s elapsed  0m5s remaining
# 404/500 complete  17.61 images/sec  0m22s elapsed  0m5s remaining
# 405/500 complete  17.62 images/sec  0m22s elapsed  0m5s remaining
# 406/500 complete  17.63 images/sec  0m23s elapsed  0m5s remaining
# 407/500 complete  17.63 images/sec  0m23s elapsed  0m5s remaining
# 408/500 complete  17.64 images/sec  0m23s elapsed  0m5s remaining
# 409/500 complete  17.65 images/sec  0m23s elapsed  0m5s remaining
# 410/500 complete  17.66 images/sec  0m23s elapsed  0m5s remaining
# 411/500 complete  17.67 images/sec  0m23s elapsed  0m5s remaining
# 412/500 complete  17.63 images/sec  0m23s elapsed  0m4s remaining
# 413/500 complete  17.62 images/sec  0m23s elapsed  0m4s remaining
# 414/500 complete  17.63 images/sec  0m23s elapsed  0m4s remaining
# 415/500 complete  17.64 images/sec  0m23s elapsed  0m4s remaining
# 416/500 complete  17.65 images/sec  0m23s elapsed  0m4s remaining
# 417/500 complete  17.66 images/sec  0m23s elapsed  0m4s remaining
# 418/500 complete  17.66 images/sec  0m23s elapsed  0m4s remaining
# 419/500 complete  17.68 images/sec  0m23s elapsed  0m4s remaining
# 420/500 complete  17.69 images/sec  0m23s elapsed  0m4s remaining
# 421/500 complete  17.69 images/sec  0m23s elapsed  0m4s remaining
# 422/500 complete  17.70 images/sec  0m23s elapsed  0m4s remaining
# 423/500 complete  17.72 images/sec  0m23s elapsed  0m4s remaining
# 424/500 complete  17.73 images/sec  0m23s elapsed  0m4s remaining
# 425/500 complete  17.75 images/sec  0m23s elapsed  0m4s remaining
# 426/500 complete  17.77 images/sec  0m23s elapsed  0m4s remaining
# 427/500 complete  17.78 images/sec  0m24s elapsed  0m4s remaining
# 428/500 complete  17.80 images/sec  0m24s elapsed  0m4s remaining
# 429/500 complete  17.82 images/sec  0m24s elapsed  0m3s remaining
# 430/500 complete  17.84 images/sec  0m24s elapsed  0m3s remaining
# 431/500 complete  17.85 images/sec  0m24s elapsed  0m3s remaining
# 432/500 complete  17.87 images/sec  0m24s elapsed  0m3s remaining
# 433/500 complete  17.88 images/sec  0m24s elapsed  0m3s remaining
# 434/500 complete  17.89 images/sec  0m24s elapsed  0m3s remaining
# 435/500 complete  17.90 images/sec  0m24s elapsed  0m3s remaining
# 436/500 complete  17.91 images/sec  0m24s elapsed  0m3s remaining
# 437/500 complete  17.93 images/sec  0m24s elapsed  0m3s remaining
# 438/500 complete  17.94 images/sec  0m24s elapsed  0m3s remaining
# 439/500 complete  17.95 images/sec  0m24s elapsed  0m3s remaining
# 440/500 complete  17.96 images/sec  0m24s elapsed  0m3s remaining
# 441/500 complete  17.98 images/sec  0m24s elapsed  0m3s remaining
# 442/500 complete  17.98 images/sec  0m24s elapsed  0m3s remaining
# 443/500 complete  17.99 images/sec  0m24s elapsed  0m3s remaining
# 444/500 complete  17.99 images/sec  0m24s elapsed  0m3s remaining
# 445/500 complete  18.00 images/sec  0m24s elapsed  0m3s remaining
# 446/500 complete  18.02 images/sec  0m24s elapsed  0m2s remaining
# 447/500 complete  18.04 images/sec  0m24s elapsed  0m2s remaining
# 448/500 complete  18.05 images/sec  0m24s elapsed  0m2s remaining
# 449/500 complete  18.06 images/sec  0m24s elapsed  0m2s remaining
# 450/500 complete  18.08 images/sec  0m24s elapsed  0m2s remaining
# 451/500 complete  18.10 images/sec  0m24s elapsed  0m2s remaining
# 452/500 complete  18.11 images/sec  0m24s elapsed  0m2s remaining
# 453/500 complete  18.13 images/sec  0m24s elapsed  0m2s remaining
# 454/500 complete  18.14 images/sec  0m25s elapsed  0m2s remaining
# 455/500 complete  18.16 images/sec  0m25s elapsed  0m2s remaining
# 456/500 complete  18.18 images/sec  0m25s elapsed  0m2s remaining
# 457/500 complete  18.20 images/sec  0m25s elapsed  0m2s remaining
# 458/500 complete  18.22 images/sec  0m25s elapsed  0m2s remaining
# 459/500 complete  18.23 images/sec  0m25s elapsed  0m2s remaining
# 460/500 complete  18.24 images/sec  0m25s elapsed  0m2s remaining
# 461/500 complete  18.25 images/sec  0m25s elapsed  0m2s remaining
# 462/500 complete  18.26 images/sec  0m25s elapsed  0m2s remaining
# 463/500 complete  18.21 images/sec  0m25s elapsed  0m2s remaining
# 464/500 complete  18.21 images/sec  0m25s elapsed  0m1s remaining
# 465/500 complete  18.22 images/sec  0m25s elapsed  0m1s remaining
# 466/500 complete  18.23 images/sec  0m25s elapsed  0m1s remaining
# 467/500 complete  18.24 images/sec  0m25s elapsed  0m1s remaining
# 468/500 complete  18.26 images/sec  0m25s elapsed  0m1s remaining
# 469/500 complete  18.27 images/sec  0m25s elapsed  0m1s remaining
# 470/500 complete  18.29 images/sec  0m25s elapsed  0m1s remaining
# 471/500 complete  18.31 images/sec  0m25s elapsed  0m1s remaining
# 472/500 complete  18.32 images/sec  0m25s elapsed  0m1s remaining
# 473/500 complete  18.33 images/sec  0m25s elapsed  0m1s remaining
# 474/500 complete  18.34 images/sec  0m25s elapsed  0m1s remaining
# 475/500 complete  18.32 images/sec  0m25s elapsed  0m1s remaining
# 476/500 complete  18.34 images/sec  0m25s elapsed  0m1s remaining
# 477/500 complete  18.30 images/sec  0m26s elapsed  0m1s remaining
# 478/500 complete  18.29 images/sec  0m26s elapsed  0m1s remaining
# 479/500 complete  18.29 images/sec  0m26s elapsed  0m1s remaining
# 480/500 complete  18.30 images/sec  0m26s elapsed  0m1s remaining
# 481/500 complete  18.31 images/sec  0m26s elapsed  0m1s remaining
# 482/500 complete  18.32 images/sec  0m26s elapsed  0m0s remaining
# 483/500 complete  18.33 images/sec  0m26s elapsed  0m0s remaining
# 484/500 complete  18.35 images/sec  0m26s elapsed  0m0s remaining
# 485/500 complete  18.36 images/sec  0m26s elapsed  0m0s remaining
# 486/500 complete  18.38 images/sec  0m26s elapsed  0m0s remaining
# 487/500 complete  18.39 images/sec  0m26s elapsed  0m0s remaining
# 488/500 complete  18.40 images/sec  0m26s elapsed  0m0s remaining
# 489/500 complete  18.42 images/sec  0m26s elapsed  0m0s remaining
# 490/500 complete  18.43 images/sec  0m26s elapsed  0m0s remaining
# 491/500 complete  18.45 images/sec  0m26s elapsed  0m0s remaining
# 492/500 complete  18.46 images/sec  0m26s elapsed  0m0s remaining
# 493/500 complete  18.48 images/sec  0m26s elapsed  0m0s remaining
# 494/500 complete  18.49 images/sec  0m26s elapsed  0m0s remaining
# 495/500 complete  18.50 images/sec  0m26s elapsed  0m0s remaining
# 496/500 complete  18.50 images/sec  0m26s elapsed  0m0s remaining
# 497/500 complete  18.52 images/sec  0m26s elapsed  0m0s remaining
# 498/500 complete  18.53 images/sec  0m26s elapsed  0m0s remaining
# 499/500 complete  18.54 images/sec  0m26s elapsed  0m0s remaining
# 500/500 complete  18.54 images/sec  0m26s elapsed  0m0s remaining
